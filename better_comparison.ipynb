# %%
from nim import *
from qlearning import * 
from sarsa import *
from play import *

# %% [markdown]
# Compare Q learning to a random opponent

# %%
q1 = Qlearning(0.1, 0.5, 0.2)
q2 = Qlearning(0.5, 0.5, 0.2)
q3 = Qlearning(0.1, 1, 0.2)
q4 = Qlearning(0.5, 1, 0.2)
q5 = Qlearning(0.1, 0.5, 0.8)
q6 = Qlearning(0.5, 0.5, 0.8)
q7 = Qlearning(0.1, 1, 0.8)
q8 = Qlearning(0.5, 1, 0.8)

Q = [q1, q2, q3, q4, q5, q6, q7, q8]

num_trainings = [100, 500, 1000, 2500, 5000, 10000, 12500]

q_names = ["Qlearning(0.1, 0.5, 0.2", "Qlearning(0.5, 0.5, 0.2", "Qlearning(0.1, 1, 0.2)", "Qlearning(0.5, 1, 0.2)", "Qlearning(0.1, 0.5, 0.8)", "Qlearning(0.5, 0.5, 0.8)", "Qlearning(0.1, 1, 0.8)", "Qlearning(0.5, 1, 0.8)"]

# %%
s1 = SarsaAlgorithm(0.1, 0.5, 0.2)
s2 = SarsaAlgorithm(0.5, 0.5, 0.2)
s3 = SarsaAlgorithm(0.1, 1, 0.2)
s4 = SarsaAlgorithm(0.5, 1, 0.2)
s5 = SarsaAlgorithm(0.1, 0.5, 0.8)
s6 = SarsaAlgorithm(0.5, 0.5, 0.8)
s7 = SarsaAlgorithm(0.1, 1, 0.8)
s8 = SarsaAlgorithm(0.5, 1, 0.8)

S = [s1, s2, s3, s4, s5, s6, s7, s8]

num_trainings = [100, 500, 1000, 2500, 5000, 10000, 12500]

s_names = ["SarsaAlgorithm(0.1, 0.5, 0.2", "SarsaAlgorithm(0.5, 0.5, 0.2", "SarsaAlgorithm(0.1, 1, 0.2)", "SarsaAlgorithm(0.5, 1, 0.2)", "SarsaAlgorithm(0.1, 0.5, 0.8)", "SarsaAlgorithm(0.5, 0.5, 0.8)", "SarsaAlgorithm(0.1, 1, 0.8)", "SarsaAlgorithm(0.5, 1, 0.8)"]

# %%
def compare(algs, trainings):

    # zapomnit si moraš za vsak alg kolikokrat zmaga
    dicts = []
    for alg in algs:
        a_dict = dict()
        for t in trainings:
            piles = generate_piles(5, 10, fixed=True)
            a = train_model(t, alg, piles)
            w = random_opponent(250, a, piles, optimal_moves=False)
            a_dict[t] = w["ai"]
        dicts.append(a_dict)
    return dicts

# %%
print(compare(Q, num_trainings))
# Out:
# [{100: 199, 500: 197, 1000: 198, 2500: 183, 5000: 206, 10000: 211, 12500: 230}, {100: 188, 500: 182, 1000: 197, 2500: 198, 5000: 214, 10000: 199, 12500: 213}, {100: 193, 500: 188, 1000: 177, 2500: 208, 5000: 206, 10000: 237, 12500: 229}, {100: 143, 500: 151, 1000: 171, 2500: 170, 5000: 196, 10000: 214, 12500: 220}, {100: 163, 500: 218, 1000: 226, 2500: 215, 5000: 236, 10000: 242, 12500: 232}, {100: 171, 500: 199, 1000: 226, 2500: 221, 5000: 226, 10000: 226, 12500: 225}, {100: 175, 500: 214, 1000: 220, 2500: 229, 5000: 232, 10000: 234, 12500: 228}, {100: 155, 500: 206, 1000: 224, 2500: 239, 5000: 236, 10000: 230, 12500: 240}]

ress_smart = [{100: 136, 500: 166, 1000: 188, 2500: 193, 5000: 200, 10000: 208, 12500: 215}, {100: 140, 500: 169, 1000: 207, 2500: 202, 5000: 204, 10000: 226, 12500: 223}, {100: 136, 500: 181, 1000: 184, 2500: 188, 5000: 203, 10000: 217, 12500: 216}, {100: 153, 500: 169, 1000: 187, 2500: 192, 5000: 206, 10000: 203, 12500: 232}, {100: 148, 500: 205, 1000: 209, 2500: 218, 5000: 235, 10000: 235, 12500: 231}, {100: 177, 500: 217, 1000: 219, 2500: 225, 5000: 222, 10000: 220, 12500: 238}, {100: 165, 500: 200, 1000: 220, 2500: 227, 5000: 212, 10000: 243, 12500: 234}, {100: 171, 500: 196, 1000: 218, 2500: 217, 5000: 236, 10000: 243, 12500: 242}]

resq = [{100: 180, 500: 213, 1000: 230, 2500: 246, 5000: 245, 10000: 250, 12500: 249}, {100: 192, 500: 216, 1000: 242, 2500: 232, 5000: 247, 10000: 250, 12500: 250}, {100: 177, 500: 222, 1000: 228, 2500: 238, 5000: 245, 10000: 239, 12500: 246}, {100: 192, 500: 212, 1000: 225, 2500: 241, 5000: 243, 10000: 247, 12500: 247}, {100: 179, 500: 198, 1000: 234, 2500: 239, 5000: 245, 10000: 245, 12500: 247}, {100: 176, 500: 216, 1000: 228, 2500: 232, 5000: 249, 10000: 240, 12500: 245}, {100: 174, 500: 220, 1000: 214, 2500: 245, 5000: 239, 10000: 244, 12500: 250}, {100: 185, 500: 215, 1000: 238, 2500: 229, 5000: 249, 10000: 248, 12500: 250}]
ress = [{100: 181, 500: 208, 1000: 226, 2500: 242, 5000: 243, 10000: 250, 12500: 250}, {100: 185, 500: 223, 1000: 240, 2500: 232, 5000: 236, 10000: 246, 12500: 247}, {100: 186, 500: 224, 1000: 214, 2500: 244, 5000: 242, 10000: 249, 12500: 250}, {100: 196, 500: 215, 1000: 226, 2500: 243, 5000: 245, 10000: 247, 12500: 243}, {100: 186, 500: 203, 1000: 214, 2500: 222, 5000: 234, 10000: 233, 12500: 234}, {100: 170, 500: 220, 1000: 226, 2500: 230, 5000: 227, 10000: 232, 12500: 232}, {100: 182, 500: 221, 1000: 227, 2500: 230, 5000: 246, 10000: 246, 12500: 233}, {100: 180, 500: 212, 1000: 228, 2500: 232, 5000: 231, 10000: 241, 12500: 242}]

# %%
def prepare_graph(dict_list, num_trainings):
    X = num_trainings
    Y = []
    for d in dict_list:
        y = []
        for key in d:
            y.append(d[key])
        Y.append(y)
    return (X, Y)

# %%
print(prepare_graph(resq, num_trainings))
# Out:
# ([100, 500, 1000, 2500, 5000, 10000, 12500], [[199, 197, 198, 183, 206, 211, 230], [188, 182, 197, 198, 214, 199, 213], [193, 188, 177, 208, 206, 237, 229], [143, 151, 171, 170, 196, 214, 220], [163, 218, 226, 215, 236, 242, 232], [171, 199, 226, 221, 226, 226, 225], [175, 214, 220, 229, 232, 234, 228], [155, 206, 224, 239, 236, 230, 240]])

# %%
import matplotlib.pyplot as plt

(X, Y) = prepare_graph(resq, num_trainings)

for y in Y:
    plt.plot(X, y)
  
# Function add a legend  
plt.legend(q_names)#, loc ="lower right")
  
# function to show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

(X, Y) = prepare_graph(ress, num_trainings)

for y in Y:
    plt.plot(X, y)
  
# Function add a legend  
plt.legend(s_names)#, loc ="lower right")
  
# function to show the plot
plt.show()

# %% [markdown]
# From this analysis we decide we will only work with
#
# * Qlearning(0.5, 0.5, 0.2)
# * SarsaAlgorithm(0.1, 0.5, 0.2)
#
# under assumtions we will train models for at least 10 000 times

# %%
from play import random_opponent_minimax

depths = [1, 2, 3, 4, 5, 7, 10]

depth_dict = dict()
for depth in depths:
    w = random_opponent_minimax(20, [5, 5, 5], depth, timing=False, optimal_moves=False)
    depth_dict[depth] = w["Minimax"]
    print(depth_dict)
# Out:
# {1: 10}
# {1: 10, 2: 10}
# {1: 10, 2: 10, 3: 10}
# {1: 10, 2: 10, 3: 10, 4: 9}
# {1: 10, 2: 10, 3: 10, 4: 9, 5: 11}
# {1: 10, 2: 10, 3: 10, 4: 9, 5: 11, 7: 10}
# {1: 10, 2: 10, 3: 10, 4: 9, 5: 11, 7: 10, 10: 10}

# %%
import matplotlib.pyplot as plt

X = depths
Y = list(depth_dict.values())

plt.plot(X,Y)

plt.ylim([0, 12])
plt.show()

# %%
# q learning vs sarsa

from qlearning import *
from sarsa import *
from play import *

num_trainings = [100, 500, 1000, 2500, 5000, 10000, 12500]

q = Qlearning(0.5, 0.5, 0.2)
s = SarsaAlgorithm(0.1, 0.5, 0.2)

wq, ws = dict(), dict()
for num in [10000, 12500]:
    wq[num] = 0
    ws[num] = 0
    for i in range(20):
        piles = generate_piles(5, 10, fixed=True)
        qq = train_model(num, q, piles)
        ss = train_model(num, s, piles)
        wins = qlearn_vs_sarsa(1, qq, ss, piles, optimal_actions=False)
        # print(wins)
        a = wins["SARSA"]
        ws[num] += a
        wq[num] += 1 - a
    print("next")
    print(ws)
    print(wq)
print(ws)
print(wq)
# Out:
# next
# {10000: 7}
# {10000: 13}
# next
# {10000: 7, 12500: 0}
# {10000: 13, 12500: 20}
# {10000: 7, 12500: 0}
# {10000: 13, 12500: 20}

# %%
ws = {100: 32, 500: 40, 1000: 22, 2500: 12, 5000: 7, 10000: 7, 12500: 0}
wq = {100: 68, 500: 60, 1000: 78, 2500: 88, 5000: 93, 10000: 13, 12500:20}

# %%
import plotly.graph_objects as go
# num_trainings = [100, 500, 1000, 2500, 5000, 10000, 12500]
trainings=['100', '500', '1000', "2500", "5000", "10000", "12500"]


fig = go.Figure(data=[
    go.Bar(name='Qlearning(0.5, 0.5, 0.2)', x=trainings, y=list(wq.values())),
    go.Bar(name='SarsaAlgorithm(0.1, 0.5, 0.2)', x=trainings, y=list(ws.values()))
])
# Change the bar mode
fig.update_layout(barmode='group')
fig.show()

# %%
# algorithm vs minimax - fix depth!
dictq, dicts = dict(), dict()
for num in num_trainings:
    winsq = alg_vs_minimax(q, 10, num, optimal_moves=False)
    dictq[num] = 10 - winsq["Minimax"]
    winss = alg_vs_minimax(s, 10, num, optimal_moves=False)
    dicts[num] = 10 - winss["Minimax"]
    print(winsq)
    print(winss)
# Out:
# {'Other algorithm': 8, 'Minimax': 2}
# {'Other algorithm': 7, 'Minimax': 3}
# {'Other algorithm': 9, 'Minimax': 1}
# {'Other algorithm': 10, 'Minimax': 0}
# {'Other algorithm': 10, 'Minimax': 0}
# {'Other algorithm': 10, 'Minimax': 0}
# {'Other algorithm': 10, 'Minimax': 0}
# {'Other algorithm': 9, 'Minimax': 1}
# {'Other algorithm': 10, 'Minimax': 0}
# {'Other algorithm': 9, 'Minimax': 1}
# {'Other algorithm': 10, 'Minimax': 0}
# {'Other algorithm': 9, 'Minimax': 1}
# {'Other algorithm': 10, 'Minimax': 0}
# {'Other algorithm': 10, 'Minimax': 0}

# %%
minq = [8, 9, 10, 10, 10, 10, 10]
mins = [7, 9, 10, 10, 9, 9, 10]

import matplotlib.pyplot as plt

X = num_trainings
Y1 = list(minq)
Y2 = mins

plt.plot(X,Y1)
plt.plot(X, Y2)

plt.ylim([0, 12])
plt.show()

# %%
# imamo q in s in samo na njiju nas zanima kako dobro se naučita optimalne strategije

def determine_ratio(result):
    a, b = 0,0
    for elt in result:
        a += elt[0]
        b += elt[1]
    if a != 0:
        return b / a
    else:
        return 0

q = Qlearning(0.5, 0.5, 0.2)
s = SarsaAlgorithm(0.1, 0.5, 0.2)

num_trainings = [100, 500, 1000, 2500, 5000, 10000, 15000, 20000, 50000, 100000]


RS, RQ = [], []
for i in range(10):
    resultsr, resultss =dict(), dict()
    for t in num_trainings:
        # p = generate_piles(5, 10)
        p = [10, 10, 10, 10, 10]
        qq = train_model(t, q, p)
        ss = train_model(t, s, p)
        ar = random_opponent(500, qq, p, optimal_moves=True)
        br = random_opponent(500, ss, p, optimal_moves=True)
        # ass = smart_opponent(500, qq, p, optimal_moves=True)
        resultr = determine_ratio(ar)
        results = determine_ratio(br)
        resultsr[t] = resultr
        resultss[t] = results
        # print(resultsr)
        # print(resultss)
    RQ.append(resultsr)
    RS.append(resultss)
    print("evo: " + str(RQ))
    # RQ.append(resultss)
# Out:
# {'ai': 400, 'random opponent': 100}
# {'ai': 350, 'random opponent': 150}
# {'ai': 248, 'random opponent': 252}
# {'ai': 257, 'random opponent': 243}
# {'ai': 446, 'random opponent': 54}
# {'ai': 446, 'random opponent': 54}
# {'ai': 477, 'random opponent': 23}
# {'ai': 479, 'random opponent': 21}
# {'ai': 462, 'random opponent': 38}
# {'ai': 449, 'random opponent': 51}
# {'ai': 500, 'random opponent': 0}
# {'ai': 500, 'random opponent': 0}
# {'ai': 499, 'random opponent': 1}
# {'ai': 498, 'random opponent': 2}
# {'ai': 500, 'random opponent': 0}
# {'ai': 500, 'random opponent': 0}
# {'ai': 441, 'random opponent': 59}
# {'ai': 441, 'random opponent': 59}
# {'ai': 500, 'random opponent': 0}
# {'ai': 500, 'random opponent': 0}
# evo: [{100: 0.2975319926873857, 500: 0, 1000: 0.28489483747609945, 2500: 1.0, 5000: 1.0, 10000: 1.0, 15000: 0.7095238095238096, 20000: 1.0, 50000: 1.0, 100000: 1.0}]
# {'ai': 459, 'random opponent': 41}
# {'ai': 444, 'random opponent': 56}
# ...

# %%
shraniRQ = RQ
shraniRS = RS
RQ
# Out:
# [{100: 0.2975319926873857,
#   500: 0,
#   1000: 0.28489483747609945,
#   2500: 1.0,
#   5000: 1.0,
#   10000: 1.0,
#   15000: 0.7095238095238096,
#   20000: 1.0,
#   50000: 1.0,
#   100000: 1.0},
#  {100: 1.0,
#   500: 0.543731778425656,
#   1000: 0.46028338342636327,
#   2500: 0.5924551638837353,
#   5000: 1.0,
#   10000: 1.0,
#   15000: 1.0,
#   20000: 1.0,
#   50000: 1.0,
#   100000: 1.0},
#  {100: 0.4748294900941864,
#   500: 0.3758556316116988,
#   1000: 1.0,
#   2500: 0.9441786283891547,
#   5000: 1.0,
#   10000: 1.0,
#   15000: 1.0,
#   20000: 0.6042845594179467,
#   50000: 0,
#   100000: 0.7704414587332054},
#  {100: 1.0,
#   500: 0.8932038834951457,
#   1000: 0.9912854030501089,
#   2500: 0,
#   5000: 0.8061497326203209,
#   10000: 1.0,
#   15000: 1.0,
#   20000: 0.9919750334373607,
#   50000: 1.0,
#   100000: 1.0},
#  {100: 0.7128082736674622,
#   500: 1.0,
#   1000: 0.564755838641189,
#   2500: 0.9638958858102435,
#   5000: 1.0,
#   10000: 1.0,
#   15000: 1.0,
# ...

# %%
resultsqr1 = {100: 0.29374584165003326, 500: 0.32142857142857145, 1000: 1.0, 2500: 1.0, 5000: 0.6687170474516696, 10000: 1.0, 12500: 0.9904458598726115}
resultsqr2 = {100: 1.0, 500: 0.4813256180957391, 1000: 0.3656565656565657, 2500: 0.9312920089619119, 5000: 1.0, 10000: 1.0, 12500: 1.0}
resultsqr3 = {100: 0.5597082953509571, 500: 1.0, 1000: 0.5457332652018395, 2500: 1.0, 5000: 0.37575542125844297, 10000: 1.0, 12500: 0.5052083333333334}
resultsqr4 = {100: 0, 500: 0.2728405315614618, 1000: 0.3046875, 2500: 1.0, 5000: 0.4463157894736842, 10000: 1.0, 12500: 1.0}
resultsqr5 = {100: 1.0, 500: 0.9176587301587301, 1000: 0.3350582147477361, 2500: 0.5640674874601003, 5000: 1.0, 10000: 1.0, 12500: 0.9894472361809046}




resultssr1 = {100: 0.2441923284710967, 500: 0.303245887060916, 1000: 0.2643510054844607, 2500: 0.7886513157894737, 5000: 1.0, 10000: 1.0, 12500: 0.6953807740324595}
resultssr2 = {100: 0.7036450079239303, 500: 0.2867820613690008, 1000: 1.0, 2500: 0, 5000: 1.0, 10000: 0.4191279887482419, 12500: 0.42083333333333334}
resultssr3 = {100: 0.9354838709677419, 500: 0.9138321995464853, 1000: 0.3646944713870029, 2500: 0.4990128331688055, 5000: 0.47872797593467986, 10000: 1.0, 12500: 0.8218390804597702}
resultssr4 = {100: 0.4714285714285714, 500: 1.0, 1000: 0.3460570469798658, 2500: 1.0, 5000: 1.0, 10000: 0.4045694200351494, 12500: 0.9988851727982163}
000: 0.7420289855072464}, {100: 0.40196882690730107, 500: 1.0, 1000: 0.7874203821656051, 2500: 0.7571976967370442, 5000: 0.8520489622139436, 10000: 0.45295404814004375, 15000: 1.0, 20000: 1.0, 50000: 0.8000867302688638}, {100: 1.0, 500: 0.6014344262295082, 1000: 0.5581597222222222, 2500: 0, 5000: 0.7388535031847133, 10000: 0.7695738354806739, 15000: 0.8585766423357665, 20000: 1.0, 50000: 1.0}, {100: 0.3856332703213611, 500: 0.4220472440944882, 1000: 0.9783577339274347, 2500: 1.0, 5000: 1.0, 10000: 1.0, 15000: 0, 20000: 0.6241480038948394, 50000: 0.7830900855561147}, {100: 0.5532098233520034, 500: 0.6937826844857641, 1000: 0.6588921282798834, 2500: 0.7727272727272727, 5000: 0.5870524767042667, 10000: 1.0, 15000: 1.0, 20000: 1.0, 50000: 0.678427869584636}, {100: 0.792675356921167, 500: 0.9579894973743436, 1000: 1.0, 2500: 1.0, 5000: 0.5749478079331941, 10000: 1.0, 15000: 0.9889178617992177, 20000: 0.678714859437751, 50000: 0.8080330773774365}, {100: 0.9516231699554424, 500: 1.0, 1000: 1.0, 2500: 0.9537037037037037, 5000: 0.5542307692307692, 10000: 1.0, 15000: 0.604199066874028, 20000: 1.0, 50000: 1.0}]

# RQ = shraniRQ
# RS = shraniRS

# Y1 = 
# RQ.remove(RQ[7])
# RQ.remove(RQ[2])
# RS.remove(RS[7])
# RS.remove(RS[2])
Y1 = RQ
Y2 = RS

import matplotlib.pyplot as plt

X = num_trainings
for y in Y2:
    plt.plot(X,list(y.values()), "red")
for y in Y1:
    plt.plot(X, list(y.values()), "blue")

# plt.legend("Qlearning", "SARSA")
plt.ylim([0, 1.2])
plt.show()

# %%
# q
Y1 = [{100: 0.8575525812619503, 500: 0.6677713338856669, 1000: 1.0, 2500: 1.0, 5000: 0.9710055521283159, 10000: 1.0, 15000: 0.9944162436548223, 20000: 1.0, 50000: 1.0}, {100: 1.0, 500: 1.0, 1000: 1.0, 2500: 1.0, 5000: 1.0, 10000: 1.0, 15000: 1.0, 20000: 1.0, 50000: 0.6303863298662704}, {100: 0.9418483904465212, 500: 0.8129269574356279, 1000: 0.7164031620553359, 2500: 0.9357466063348416, 5000: 1.0, 10000: 1.0, 15000: 1.0, 20000: 0.9960543621218764, 50000: 1.0}, {100: 1.0, 500: 0.7824133504492939, 1000: 1.0, 2500: 1.0, 5000: 0.706984667802385, 10000: 1.0, 15000: 0.5248138957816377, 20000: 1.0, 50000: 1.0}, {100: 0.4722401549386701, 500: 1.0, 1000: 1.0, 2500: 1.0, 5000: 0.9462631253860407, 10000: 1.0, 15000: 1.0, 20000: 0.9948884758364313, 50000: 1.0}, {100: 1.0, 500: 1.0, 1000: 1.0, 2500: 0.6969006381039198, 5000: 1.0, 10000: 1.0, 15000: 1.0, 20000: 1.0, 50000: 1.0}, {100: 0.9406698564593301, 500: 1.0, 1000: 0.5598918083462133, 2500: 1.0, 5000: 1.0, 10000: 0.9989035087719298, 15000: 0, 20000: 0.6581291759465479, 50000: 1.0}, {100: 0.9462102689486552, 500: 1.0, 1000: 1.0, 2500: 0.9841443411700382, 5000: 0.5435998683777559, 10000: 1.0, 15000: 1.0, 20000: 1.0, 50000: 1.0}, {100: 1.0, 500: 1.0, 1000: 1.0, 2500: 1.0, 5000: 1.0, 10000: 1.0, 15000: 0.9832589285714286, 20000: 1.0, 50000: 1.0}, {100: 0.7455775234131113, 500: 1.0, 1000: 1.0, 2500: 1.0, 5000: 1.0, 10000: 1.0, 15000: 1.0, 20000: 1.0, 50000: 1.0}]
# s
Y2 = [{100: 0.32006010518407213, 500: 1.0, 1000: 0.265702479338843, 2500: 1.0, 5000: 0.43654114365411434, 10000: 1.0, 15000: 0.6155268022181146, 20000: 0, 50000: 1.0}, {100: 0.24375624375624375, 500: 0.5139844108207244, 1000: 1.0, 2500: 1.0, 5000: 1.0, 10000: 0.9796999117387467, 15000: 1.0, 20000: 1.0, 50000: 1.0}, {100: 0.3840548649807115, 500: 0.3111187845303867, 1000: 1.0, 2500: 0.5404428377767736, 5000: 1.0, 10000: 0.9786845310596833, 15000: 1.0, 20000: 0.7746793084216397, 50000: 1.0}, {100: 0.31000781860828774, 500: 0.5715583825533849, 1000: 1.0, 2500: 1.0, 5000: 1.0, 10000: 1.0, 15000: 1.0, 20000: 1.0, 50000: 0.7420289855072464}, {100: 0.40196882690730107, 500: 1.0, 1000: 0.7874203821656051, 2500: 0.7571976967370442, 5000: 0.8520489622139436, 10000: 0.45295404814004375, 15000: 1.0, 20000: 1.0, 50000: 0.8000867302688638}, {100: 1.0, 500: 0.6014344262295082, 1000: 0.5581597222222222, 2500: 0, 5000: 0.7388535031847133, 10000: 0.7695738354806739, 15000: 0.8585766423357665, 20000: 1.0, 50000: 1.0}, {100: 0.3856332703213611, 500: 0.4220472440944882, 1000: 0.9783577339274347, 2500: 1.0, 5000: 1.0, 10000: 1.0, 15000: 0, 20000: 0.6241480038948394, 50000: 0.7830900855561147}, {100: 0.5532098233520034, 500: 0.6937826844857641, 1000: 0.6588921282798834, 2500: 0.7727272727272727, 5000: 0.5870524767042667, 10000: 1.0, 15000: 1.0, 20000: 1.0, 50000: 0.678427869584636}, {100: 0.792675356921167, 500: 0.9579894973743436, 1000: 1.0, 2500: 1.0, 5000: 0.5749478079331941, 10000: 1.0, 15000: 0.9889178617992177, 20000: 0.678714859437751, 50000: 0.8080330773774365}, {100: 0.9516231699554424, 500: 1.0, 1000: 1.0, 2500: 0.9537037037037037, 5000: 0.5542307692307692, 10000: 1.0, 15000: 0.604199066874028, 20000: 1.0, 50000: 1.0}]

Y1 = RQ
Y2 = RS

import matplotlib.pyplot as plt

X = num_trainings

for y in Y1:
    plt.plot(X, list(y.values()), "blue")
for y in Y2:
    plt.plot(X,list(y.values()), "red")
# plt.legend("Qlearning", "SARSA")
plt.ylim([0, 1.2])
plt.show()
